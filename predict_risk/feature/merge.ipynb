# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
user_info_train = pd.read_csv("../data/train/user_info_train.csv")
bill_train = pd.read_csv("../data/train/bill_train.csv")

# %%
print user_info_train.head()
print bill_train.head()
# Out:
#      id  sex  job  edu  marriage  account
# 0  3150    1    2    4         1        4
# 1  6965    1    2    4         3        2
# 2  1265    1    3    4         3        1
# 3  6360    1    2    4         3        2
# 4  2583    2    2    2         1        1
#    id  avail_amount  circ_interest  consume_amount  credit_amount  \
# 0   2      0.000000            0.0        2.521739      18.638974
# 1   3      0.000000            0.0        2.000000      18.361833
# 2   4      1.014342            0.0        0.055556      16.055204
# 3   5      0.000000            0.0        0.000000      20.664418
# 4   6      2.447743            0.0        2.904762      20.567794
#
#    prepare_amount
# 0        7.087560
# 1        0.000000
# 2        7.808445
# 3       19.971271
# 4       13.788434

# %%
bill_train[bill_train['id']==[6965]]
# Out:
#         id  avail_amount  circ_interest  consume_amount  credit_amount  \
# 5973  6965           0.0       15.52068           10.75      19.971271
#
#       prepare_amount
# 5973       19.624697

# %%
df = user_info_train.merge(bill_train,on='id',how='left')
df.head()
# Out:
#      id  sex  job  edu  marriage  account  avail_amount  circ_interest  \
# 0  3150    1    2    4         1        4      0.000000       0.000000
# 1  6965    1    2    4         3        2      0.000000      15.520680
# 2  1265    1    3    4         3        1      0.000000       5.175483
# 3  6360    1    2    4         3        2      0.139432       8.235788
# 4  2583    2    2    2         1        1      0.000000       6.478271
#
#    consume_amount  credit_amount  prepare_amount
# 0        0.736842      14.181718       13.862981
# 1       10.750000      19.971271       19.624697
# 2        1.444444      19.973385        9.702118
# 3        1.666667      16.992500       13.169416
# 4        1.791667      18.307126       11.014650

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55596 entries, 0 to 55595
# Data columns (total 11 columns):
# id                55596 non-null int64
# sex               55596 non-null int64
# job               55596 non-null int64
# edu               55596 non-null int64
# marriage          55596 non-null int64
# account           55596 non-null int64
# avail_amount      53174 non-null float64
# circ_interest     53174 non-null float64
# consume_amount    53174 non-null float64
# credit_amount     53174 non-null float64
# prepare_amount    53174 non-null float64
# dtypes: float64(5), int64(6)
# memory usage: 5.1 MB

# %%
df[df.avail_amount.isnull()]
# Out:
#           id  sex  job  edu  marriage  account  avail_amount  circ_interest  \
# 48      4543    1    4    2         3        3           NaN            NaN
# 88      1846    1    4    4         1        1           NaN            NaN
# 96       196    1    3    4         3        2           NaN            NaN
# 102     1025    1    2    4         1        4           NaN            NaN
# 112     1709    1    2    3         1        1           NaN            NaN
# 138        1    1    2    3         1        3           NaN            NaN
# 189     2102    1    2    3         3        1           NaN            NaN
# 196    41638    1    2    3         3        2           NaN            NaN
# 198    22560    1    2    2         3        1           NaN            NaN
# 223     6145    1    2    2         1        1           NaN            NaN
# 246     2330    1    2    2         1        1           NaN            NaN
# ...
