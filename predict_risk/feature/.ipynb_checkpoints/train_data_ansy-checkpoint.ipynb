# %%
import numpy as np
import pandas as pd
user_data = pd.read_csv("../../pcredit/train/user_info_train.txt",header=None)

# %%
user_data.head()
# Out:
#       0  1  2  3  4  5
# 0  3150  1  2  4  1  4
# 1  6965  1  2  4  3  2
# 2  1265  1  3  4  3  1
# 3  6360  1  2  4  3  2
# 4  2583  2  2  2  1  1

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55596 entries, 0 to 55595
# Data columns (total 6 columns):
# 0    55596 non-null int64
# 1    55596 non-null int64
# 2    55596 non-null int64
# 3    55596 non-null int64
# 4    55596 non-null int64
# 5    55596 non-null int64
# dtypes: int64(6)
# memory usage: 2.5 MB

# %%
bank_detail_data = pd.read_csv("../../pcredit/train/bank_detail_train.txt",header=None)
bank_detail_data.head()
# Out:
#       0           1  2          3  4
# 0  6965  5894316387  0  13.756664  0
# 1  6965  5894321388  1  13.756664  0
# 2  6965  5897553564  0  14.449810  0
# 3  6965  5897563463  1  10.527763  0
# 4  6965  5897564598  1  13.651303  0

# %%
bank_detail_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6070197 entries, 0 to 6070196
# Data columns (total 5 columns):
# 0    int64
# 1    int64
# 2    int64
# 3    float64
# 4    int64
# dtypes: float64(1), int64(4)
# memory usage: 231.6 MB

# %%
import time
def int_to_time(x):
    return time.strftime("%Y-%m-%d %H:%M:%S",time.localtime(float(x)))
print int_to_time(5894316387)
# Out:
# 2156-10-13 14:06:27

# %%
bank_detail_data[1] = bank_detail_data[1].map(lambda x:time.strftime("%Y-%m-%d %H:%M:%S",time.localtime(float(x))))

# %%
bank_detail_data.head(20)
# Out:
#        0                    1  2          3  4
# 0   6965  2156-10-13 14:06:27  0  13.756664  0
# 1   6965  2156-10-13 15:29:48  1  13.756664  0
# 2   6965  2156-11-20 01:19:24  0  14.449810  0
# 3   6965  2156-11-20 04:04:23  1  10.527763  0
# 4   6965  2156-11-20 04:23:18  1  13.651303  0
# 5   6965  2156-11-20 04:23:18  1   8.235467  0
# 6   6965  2156-11-21 04:09:23  1   8.235467  0
# 7   6965  2156-11-21 04:09:23  1  13.063517  0
# 8   6965  2156-11-23 06:46:11  1   6.288647  0
# 9   6965  2156-11-23 06:55:45  1  13.063517  0
# 10  6965  2156-11-24 03:54:00  0  14.449810  0
# 11  6965  2156-11-25 16:32:48  0  15.366101  0
# 12  6965  2156-11-25 16:46:23  1  15.366101  0
# 13  6965  2156-11-25 16:47:12  1  14.162128  0
# 14  6965  2156-11-26 02:26:57  1   8.928481  0
# 15  6965  2156-11-26 02:30:36  1   9.141549  0
# 16  6965  2156-11-26 08:10:21  1   7.947873  0
# 17  6965  2156-11-27 01:27:46  1   7.542585  0
# 18  6965  2156-11-30 03:20:28  1  13.063517  0
# ...

# %%
# 写入文件
bank_detail_data.to_csv("../../pcredit/train/bank_timefomat_train.txt",header=None)

# %%
bank_detail_6965 = bank_detail_data[bank_detail_data[0]==6965]
bank_detail_6965
# Out:
#         0                    1  2          3  4
# 0    6965  2156-10-13 14:06:27  0  13.756664  0
# 1    6965  2156-10-13 15:29:48  1  13.756664  0
# 2    6965  2156-11-20 01:19:24  0  14.449810  0
# 3    6965  2156-11-20 04:04:23  1  10.527763  0
# 4    6965  2156-11-20 04:23:18  1  13.651303  0
# 5    6965  2156-11-20 04:23:18  1   8.235467  0
# 6    6965  2156-11-21 04:09:23  1   8.235467  0
# 7    6965  2156-11-21 04:09:23  1  13.063517  0
# 8    6965  2156-11-23 06:46:11  1   6.288647  0
# 9    6965  2156-11-23 06:55:45  1  13.063517  0
# 10   6965  2156-11-24 03:54:00  0  14.449810  0
# 11   6965  2156-11-25 16:32:48  0  15.366101  0
# 12   6965  2156-11-25 16:46:23  1  15.366101  0
# 13   6965  2156-11-25 16:47:12  1  14.162128  0
# 14   6965  2156-11-26 02:26:57  1   8.928481  0
# 15   6965  2156-11-26 02:30:36  1   9.141549  0
# 16   6965  2156-11-26 08:10:21  1   7.947873  0
# 17   6965  2156-11-27 01:27:46  1   7.542585  0
# 18   6965  2156-11-30 03:20:28  1  13.063517  0
# ...

# %%
dd = bank_detail_6965[bank_detail_6965[2]==0][3]
import matplotlib.pyplot as plt

# %%
d = bank_detail_6965[bank_detail_6965[2]==1][3]
d.plot(label="1")
dd.plot(c='r',label="0")
plt.legend()
plt.grid()
plt.show()

# %%
print "0 标签的均值:",dd.mean(),"  1 标签的均值:",d.mean()
# Out:
# 0 标签的均值: 12.9713363733   1 标签的均值: 11.1921521626

# %%
plt_6965 = bank_detail_6965[[2,3]]
plt_6965
# Out:
#      2          3
# 0    0  13.756664
# 1    1  13.756664
# 2    0  14.449810
# 3    1  10.527763
# 4    1  13.651303
# 5    1   8.235467
# 6    1   8.235467
# 7    1  13.063517
# 8    1   6.288647
# 9    1  13.063517
# 10   0  14.449810
# 11   0  15.366101
# 12   1  15.366101
# 13   1  14.162128
# 14   1   8.928481
# 15   1   9.141549
# 16   1   7.947873
# 17   1   7.542585
# 18   1  13.063517
# 19   0  15.424370
# 20   0  12.840374
# 21   1  12.147230
# 22   1  15.366101
# 23   1  12.552693
# 24   1  12.147230
# 25   1   9.834643
# 26   1   7.491319
# 27   1   7.712245
# 28   1   8.407275
# 29   0  13.063517
# ..  ..        ...
# 334  1   6.849967
# 335  1  11.454088
# 336  1  11.454088
# 337  1  11.454088
# 338  1  10.532801
# 339  1  11.454088
# 340  1   9.839680
# 341  1  12.552693
# 342  1   6.849967
# 343  1  10.250140
# 344  0   9.839680
# 345  1  11.454088
# 346  1   7.542585
# 347  1   8.235467
# 348  1  11.454088
# 349  1   9.842691
# 350  1   2.344542
# 351  0   8.458557
# ...

# %%
pd.pivot_table(plt_6965,index=[2],values=[3])
# Out:
#            3
# 2
# 0  12.971336
# 1  11.192152

# %%
bill_detail_data = pd.read_csv("../../pcredit/train/bill_detail_train.txt",header=None)
bill_detail_data.head()
# Out:
#      0           1   2          3          4          5          6   \
# 0  3150  5906744363   6  18.626118  18.661937  20.664418  18.905766
# 1  3150  5906744401   6  18.905766  18.909954  20.664418  19.113305
# 2  3150  5906744427   6  19.113305  19.150290  20.664418  19.300194
# 3  3150  5906744515   6  19.300194  19.300280  21.000890  20.303240
# 4  3150  5906744562   6  20.303240  20.307744  21.000890  20.357134
#
#           7   8    9    10   11   12         13  14
# 0  17.847133   1  0.0  0.0  0.0  0.0  19.971271   0
# 1  17.911506   1  0.0  0.0  0.0  0.0  19.971271   0
# 2  17.977610   1  0.0  0.0  0.0  0.0  19.971271   0
# 3  18.477177   1  0.0  0.0  0.0  0.0  20.307743   0
# 4  18.510985   1  0.0  0.0  0.0  0.0  20.307743   0

# %%
bill_detail_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2338118 entries, 0 to 2338117
# Data columns (total 15 columns):
# 0     int64
# 1     int64
# 2     int64
# 3     float64
# 4     float64
# 5     float64
# 6     float64
# 7     float64
# 8     int64
# 9     float64
# 10    float64
# 11    float64
# 12    float64
# 13    float64
# 14    int64
# dtypes: float64(10), int64(5)
# memory usage: 267.6 MB

# %%
loan_data = pd.read_csv("../../pcredit/train/loan_time_train.txt",header=None)
loan_data.head()
# Out:
#    0           1
# 0  1  5914855887
# 1  2  5914855887
# 2  3  5914855887
# 3  4  5914855887
# 4  5  5914855887

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55596 entries, 0 to 55595
# Data columns (total 2 columns):
# 0    55596 non-null int64
# 1    55596 non-null int64
# dtypes: int64(2)
# memory usage: 868.8 KB

# %%
over_data = pd.read_csv("../../pcredit/train/overdue_train.txt",header=None)
over_data.head()
# Out:
#    0  1
# 0  1  0
# 1  2  0
# 2  3  0
# 3  4  1
# 4  5  0

# %%
over_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55596 entries, 0 to 55595
# Data columns (total 2 columns):
# 0    55596 non-null int64
# 1    55596 non-null int64
# dtypes: int64(2)
# memory usage: 868.8 KB
